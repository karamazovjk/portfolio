# %%
print(f'Usuarios: {df.shape[0]:,}')
print(f'Idade media: {df["Age"].mean():.1f}')
print(f'Uso diario medio: {df["Daily_Phone_Hours"].mean():.1f}h')
print(f'Sono medio: {df["Sleep_Hours"].mean():.1f}h')
print(f'Dormem menos de 7h: {(df["Sleep_Hours"] < 7).mean()*100:.1f}%')
print(f'Estresse medio: {df["Stress_Level"].mean():.1f}/10')
print(f'Produtividade media: {df["Work_Productivity_Score"].mean():.1f}/10')
print(f'Correlacao sono x produtividade: {df["Sleep_Hours"].corr(df["Work_Productivity_Score"]):.3f}')
print(f'Correlacao estresse x produtividade: {df["Stress_Level"].corr(df["Work_Productivity_Score"]):.3f}')
# Out:
# Usuarios: 50,000
# Idade media: 39.0
# Uso diario medio: 6.5h
# Sono medio: 6.5h
# Dormem menos de 7h: 59.0%
# Estresse medio: 5.5/10
# Produtividade media: 5.5/10
# Correlacao sono x produtividade: 0.003
# Correlacao estresse x produtividade: 0.010

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

df = pd.read_csv('/kaggle/input/datasets/amar5693/screen-time-sleep-and-stress-analysis-dataset/Smartphone_Usage_Productivity_Dataset_50000.csv')

print("Shape:", df.shape)
print("\nPrimeiras linhas:")
print(df.head())
print("\nInfo:")
print(df.info())
print("\nEstatísticas descritivas:")
print(df.describe())

media_sono = df["Sleep_Hours"].mean()
media_estresse = df["Stress_Level"].mean()

print("\nMédia de sono:", media_sono)
print("Média de estresse:", media_estresse)
# Out:
# /kaggle/input/datasets/amar5693/screen-time-sleep-and-stress-analysis-dataset/Smartphone_Usage_Productivity_Dataset_50000.csv
# Shape: (50000, 13)
#
# Primeiras linhas:
#   User_ID  Age  Gender      Occupation Device_Type  Daily_Phone_Hours  \
# 0      U1   58    Male    Professional     Android                1.3
# 1      U2   25    Male    Professional     Android                1.2
# 2      U3   19    Male         Student         iOS                5.3
# 3      U4   35  Female  Business Owner         iOS                5.8
# 4      U5   33    Male      Freelancer     Android                7.9
#
#    Social_Media_Hours  Work_Productivity_Score  Sleep_Hours  Stress_Level  \
# 0                 6.7                        6          8.8             4
# 1                 1.5                        5          6.4             1
# 2                 5.7                        5          9.0             4
# 3                 2.5                        2          5.7             3
# ...
